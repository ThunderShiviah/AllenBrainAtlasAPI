# %%
from skimage import io, transform

import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# %matplotlib inline

# %%
# Load the two landscape photos
img0 = io.imread('../data/img/test043_TL/p1-D1-01b.jpg')
img1 = io.imread('../data/img/test043_TL/p1-D2-01b.jpg')

'''look at the loaded files'''
f, (ax0, ax1) = plt.subplots(1, 2)
ax0.imshow(img0)
ax1.imshow(img1)

# %%
def choose_corresponding_points():
    """Utility function for finding corresponding features in images.

    Alternately click on image 0 and 1, indicating the same feature.

    """
    f, (ax0, ax1) = plt.subplots(1, 2)
    ax0.imshow(img0)
    ax1.imshow(img1)

    coords = plt.ginput(8, timeout=0)

    np.savez('_reg_coords.npz', source=coords[::2], target=coords[1::2])

    plt.close()


# Re use previous coordinates, if found
if not os.path.exists('_reg_coords.npz'):
    choose_corresponding_points()

coords = np.load('_reg_coords.npz')

# Estimate the transformation between the two sets of coordinates,
# assuming it is an affine transform
tf = transform.estimate_transform('similarity', coords['source'], coords['target'])

# Use a translation transformation to center both images for display purposes
offset = transform.SimilarityTransform(translation=(-200, -170))

img0_warped = transform.warp(img0, inverse_map=offset,
                             output_shape=(600, 600))

img1_warped = transform.warp(img1, inverse_map=offset + tf,
                             output_shape=(600, 600))


# Find where both images overlap; in that region average their values
mask = (img0_warped != 0) & (img1_warped != 0)
registered = img0_warped + img1_warped
registered[mask] /= 2

# Display the results
f, (ax0, ax1, ax2) = plt.subplots(1, 3, subplot_kw={'xticks': [], 'yticks': []})
ax0.imshow(img0)
ax1.imshow(img1)
ax2.imshow(registered)

# ## ## Display image boundaries
# y, x = img1.shape[:2]
# box = np.array([[0, 0], [0, y], [x, y], [x, 0], [0, 0]])
# tf_box = (offset + tf).inverse(box)
# plt.plot(tf_box[:, 0], tf_box[:, 1], 'r-')

#plt.show()
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/figure.py:362: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-11-07bd955c3505> in <module>()
#      18 # Re use previous coordinates, if found
#      19 if not os.path.exists('_reg_coords.npz'):
# ---> 20     choose_corresponding_points()
#      21
#      22 coords = np.load('_reg_coords.npz')
#
# <ipython-input-11-07bd955c3505> in choose_corresponding_points()
#       9     ax1.imshow(img1)
#      10
# ---> 11     coords = plt.ginput(8, timeout=0)
#      12
#      13     np.savez('_reg_coords.npz', source=coords[::2], target=coords[1::2])
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in ginput(*args, **kwargs)
#     482     If *timeout* is negative, does not timeout.
#     483     """
# --> 484     return gcf().ginput(*args, **kwargs)
#     485
#     486 @docstring.copy_dedent(Figure.waitforbuttonpress)
#
# /usr/lib/pymodules/python2.7/matplotlib/figure.pyc in ginput(self, n, timeout, show_clicks, mouse_add, mouse_pop, mouse_stop)
#    1459                                                         mouse_stop=mouse_stop)
#    1460         return blocking_mouse_input(n=n, timeout=timeout,
# -> 1461                                     show_clicks=show_clicks)
#    1462
#    1463     def waitforbuttonpress(self, timeout=-1):
#
# /usr/lib/pymodules/python2.7/matplotlib/blocking_input.pyc in __call__(self, n, timeout, show_clicks)
#     286         self.clicks = []
#     287         self.marks = []
# --> 288         BlockingInput.__call__(self, n=n, timeout=timeout)
#     289
#     290         return self.clicks
#
# /usr/lib/pymodules/python2.7/matplotlib/blocking_input.pyc in __call__(self, n, timeout)
#     109         try:
#     110             # Start event loop
# --> 111             self.fig.canvas.start_event_loop(timeout=timeout)
#     112         finally:  # Run even on exception like ctrl-c
#     113             # Disconnect the callbacks
#
# /usr/lib/pymodules/python2.7/matplotlib/backend_bases.pyc in start_event_loop(self, timeout)
#    2243         This is implemented only for backends with GUIs.
#    2244         """
# -> 2245         raise NotImplementedError
#    2246
#    2247     def stop_event_loop(self):
#
# NotImplementedError:
